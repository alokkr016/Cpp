# %%
def bubble_sort(arr):
    for i in range(len(arr)-1):
        for j in range(len(arr)-1):
            if arr[j] > arr[j+1]:
                arr[j],arr[j+1] = arr[j+1],arr[j]
            
    return arr
        


def main():
    arr = [12, 11, 0, 5, 6]
    print(bubble_sort(arr))

if __name__ == "__main__":
    main()
# Out:
# [0, 5, 6, 11, 12]

# %%
def dentenikk(arr):
    s = 0
    for i in arr:
        if(i % 2 != 0):
            s = s+ i
    print(s * 2)

arr = [25,24,35,20,32,41]
dentenikk(arr)
# Out:
# 202

# %%
def result_even( ):
    x = int(input("Enter a number"))
    if (x % 2 == 0):
        print("You entered an even number")
    else:
        print("Number is odd")
 
result_even()
# Out:
# You entered an even number

# %%
# Out:
# The new string is :  STs11111

# %%
def insertion_sort(arr):
    for i in range(1,len(arr)):
        key = arr[i]
        j = i-1
        while j >= 0:
            arr[j] > arr[j+1]
            j = j - 1


def main():
    arr = [12, 11, 0, 5, 6]
    print(insertion_sort(arr))

if __name__ == "__main__":
    main()

# %%
class FAN():

    
    def __init__(self):
        self.speed = "Slow"
        self.on = "False"
        self.rad = 5
        self.color = "Blue"

        
    def set_prop(self,speed,on,radius,color):
        self.speed = speed
        self.on = on
        self.rad = radius
        self.color = color

        
    def get_prop(self):
        return "Speed: "+str(self.speed) + ", \n" +str(self.on) + ", \n" + "Radius of fan: "+str(self.rad) + ", \n" + "Color of fan: "+str(self.color)



print("Speed constant\n 1. Slow \n 2. Medium \n 3. Fast")
prop = FAN()
print("\nDefault values:")
print(prop.get_prop())
print("\n1st FAN object properties: Maximum speed, ON, radius 10, and color yellow")
prop1 = FAN()
prop1.set_prop("Maximum","True",10,"Yellow")
print(prop1.get_prop())
print("\n2nd FAN object properties: Medium speed, OFF, radius 5, color blue")
prop2 = FAN()
prop2.set_prop("Slow","False",5,"Blue")
print(prop2.get_prop())
# Out:
# Speed constant
#  1. Slow
#  2. Medium
#  3. Fast
#
# Default values:
# Speed: Slow,
# False,
# Radius of fan: 5,
# Color of fan: Blue
#
# 1st FAN object properties: Maximum speed, ON, radius 10, and color yellow
# Speed: Maximum,
# True,
# Radius of fan: 10,
# Color of fan: Yellow
#
# 2nd FAN object properties: Medium speed, OFF, radius 5, color blue
# Speed: Slow,
# False,
# Radius of fan: 5,
# Color of fan: Blue

# %%
import math
class GeometricObject:
    def __init__(self, color="green", filled=True):
        self.__color = color
        self.__filled = filled
    def get_color(self):
        return self.__color
    def set_color(self, color):
        self.__color = color
    def is_filled(self):
        return self.__filled
    def set_filled(self, filled):
        self.__filled = filled
    def __str__(self):
        return "color: " + self.__color + " and filled: " + str(self.__filled)
class Triangle(GeometricObject):
    def __init__(self, side1=1.0, side2=1.0, side3=1.0, *args):
        super().__init__(*args)
        self.__side1 = side1
        self.__side2 = side2
        self.__side3 = side3 
    def get_side1(self):
        return self.__side1
    def get_side2(self):
        return self.__side2
    def get_side3(self):
        return self.__side3
    def get_perimeter(self):
        return self.__side1 + self.__side2 + self.__side3
    def get_area(self):
        p = self.get_perimeter() / 2
        area = math.sqrt(p *(p - self.__side1) *(p - self.__side2) *(p - self.__side3))
        return area
    def __str__(self): 
        info = "Triangle: side1 = {} side2 = {} side3 = {}".format(self.__side1, self.__side2,self.__side3)
        return info
if __name__ == "__main__":
 side1 = float(input('Enter side1: '))
 side2 = float(input('Enter side2: '))
 side3 = float(input('Enter side3: '))
 color = input('Enter color: ')
 filled = int(input('Enter filled: '))
 triangle = Triangle(side1, side2, side3, color, filled)
 msg = "Triangle:\n area:{}\n perimeter:{}\n color:{}\n isFilled:{}".format(triangle.get_area(),triangle.get_perimeter(),triangle.get_color(),triangle.is_filled())
 print(msg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e9f9f49cb622> in <module>
#      40  side3 = float(input('Enter side3: '))
#      41  color = input('Enter color: ')
# ---> 42  filled = int(input('Enter filled: '))
#      43  triangle = Triangle(side1, side2, side3, color, filled)
#      44  msg = "Triangle:\n area:{}\n perimeter:{}\n color:{}\n isFilled:{}".format(triangle.get_area(),triangle.get_perimeter(),triangle.get_color(),triangle.is_filled())
#
# ValueError: invalid literal for int() with base 10: 'yellow'

# %%
def bubble_sort(DATA_LIST) :
    i = 0
    j = 0
    l = len(DATA_LIST)
    for i in range(l):
        print("Bubble Sort Iterations – Asc order of Quantity")
    for j in range(i+l,l):
        if DATA_LlST[i][3] > DATA_LIST[j][3]:
# swapping
            DATA_LIST[i][0], DATA_LIST[j] [0]=DATA_LIST[j] [0],DATA_LIST[i] [0]
            DATA_LIST[i][1], DATA_LIST[j][1]=DATA_LIST[j][l],DATA_LIST[i][l]
            DATA_LIST[i][2], DATA_LIST[j] [2]=DATA_LIST[j][2],DATA_LIST[i][2]
            DATA_LIST[i][3], DATA_LIST[j][3]=DATA_LIST[j][3] ,DATA_LIST[i] [3]
    print(DATA_LIST)
def insertion_sort(DATA_LIST):
    for K in range (1, len(DATA_LIST)):
        temp=DATA_LIST[K][2]
        ptr=K-1
    print("Insertion Sort Iterations – Desc order of price")
    while(ptr>=0) and DATA_LIST[ptr][2] < temp:
        DATA_LIST[ptr+1] [0]=DATA_LIST[ptr][0]
        DATAJHST[ptr+1] [1]=DATA_LIST[ptr][1]
        DATA_LIST[ptr+1][2]=DATA_LIST[ptr][2]
        DATA_LIST[ptr+1] [3]=DATA_LIST[ptr] [3]
        ptr=ptr-1
        DATA_LIST[ptr+1][2]=temp
    print(DATA_LIST)
maxrange = input("Enter Number of Items: ")
Items=[]
for i in range (maxrange):
    Details=[]
    Details. append(input("Enter Item Code"))
    Details.append(raw_input("Enter Item name"))
    Details.append(float(raw_input("Enter price")))
    Details.append(input("Enter Quantity")) 
    Items. append(Details)
    
print("BEFORE SORTING",bubble_sort(Items),insertion_sort(Items))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-6cdd0345319d> in <module>
#      28 maxrange = input("Enter Number of Items: ")
#      29 Items=[]
# ---> 30 for i in range (maxrange):
#      31     Details=[]
#      32     Details. append(input("Enter Item Code"))
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
def binary_search(list1, n):

    low = 0

    high = len(list1) - 1

    mid = 0

    while low <= high:

        mid = (high + low) // 2

        if list1[mid] < n:

            low = mid + 1

        elif list1[mid] > n:

            high = mid - 1

        else:

            return mid

    return -1

list1 = []

num = int(input("Enter number of elements : "))

for i in range(0, num):

    val = int(input())

    list1.append(val)

    list1.sort()

print(list1)

n=int(input("enter number to be searched: "))

result = binary_search(list1, n)

if result != -1:

    print("Element is present at index", str(result+1))

else:

    print("Element is not present in list1")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d06241f9608f> in <module>
#      31 for i in range(0, num):
#      32
# ---> 33     val = int(input())
#      34
#      35     list1.append(val)
#
# ValueError: invalid literal for int() with base 10: 'jinga'

# %%
def bubble_sort(DL) :
    i = 0
    j = 0

    l = len(DL)

    print('Bubble Sort Ascending order of Quantity')
    for i in range(l):

        for j in range(i+l,l):

            if DL[i][3] > DL[j][3]:
                DL[i][0], DL[j] [0]=DL[j] [0],DL[i] [0]
                DL[i][1], DL[j][1]=DL[j][l],DL[i][l]

                DL[i] [2], DL[j] [2]=DL[j][2],DL[i][2]
                DL[i][3], DL[j][3]=DL[j][3] ,DL[i] [3]
        print (DL)

def insertion_sort(DL):
    for K in range (1, len(DL)):
        temp=DL[K][2]
        ptr=K-1

        print("Insertion Sort Descending order of       price")
        while(ptr>=0) and DL[ptr][2] < temp:
            DL[ptr+1] [0]=DL[ptr] [0]

            DL[ptr+1] [1]=DL[ptr] [1]
            DL[ptr+1][2]=DL[ptr][2]

            DL[ptr+1] [3]=DL[ptr] [3]
            ptr=ptr-1
            DL[ptr+1][2]=temp
    print (DL)

maxrange = int(input('Enter Number of Items: '))
Items=[]

for i in range(maxrange):
    Details=[]
    
    Details. append(input('Item Code: '))
    Details.append(input('Item name: '))
    Details.append(float(input('Price: ')))
    Details.append(input('Quantity: '))
    Items.append(Details)
bubble_sort(Items)
insertion_sort(Items)

# %%
def main():
    # TODO write your solution here
    height = int(input("Enter the height: "))
    height_check(height)

def height_check(height):
    if height >= 1.6 and height <= 1.9:
        print("Correct height to be an astronaut")
    elif height < 1.6:
        print("Below minimum height")
    elif height > 1.9:
        print("Above maximum astronaut height")


if __name__ == "__main__":
    main()
# Out:
# Above maximum astronaut height

# %%
# print numbers from 1 up until MAX_NUMBER, inclusive
MAX_NUMBER = 100

def main():
    # TODO write your solution here
    num = 1
    while num <= MAX_NUMBER:
        if num % 2 == 0:
            print("%d is even"%num)
        else:
            print("%d is odd"%num)
        num += 1


if __name__ == "__main__":
    main()
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
# 11 is odd
# 12 is even
# 13 is odd
# 14 is even
# 15 is odd
# 16 is even
# 17 is odd
# 18 is even
# 19 is odd
# 20 is even
# 21 is odd
# 22 is even
# 23 is odd
# 24 is even
# 25 is odd
# 26 is even
# 27 is odd
# 28 is even
# 29 is odd
# 30 is even
# 31 is odd
# 32 is even
# 33 is odd
# 34 is even
# 35 is odd
# 36 is even
# 37 is odd
# 38 is even
# 39 is odd
# 40 is even
# 41 is odd
# 42 is even
# 43 is odd
# 44 is even
# 45 is odd
# 46 is even
# 47 is odd
# 48 is even
# 49 is odd
# 50 is even
# 51 is odd
# 52 is even
# 53 is odd
# 54 is even
# 55 is odd
# 56 is even
# 57 is odd
# 58 is even
# 59 is odd
# 60 is even
# 61 is odd
# 62 is even
# 63 is odd
# 64 is even
# 65 is odd
# 66 is even
# 67 is odd
# 68 is even
# 69 is odd
# 70 is even
# 71 is odd
# 72 is even
# 73 is odd
# 74 is even
# 75 is odd
# 76 is even
# 77 is odd
# 78 is even
# 79 is odd
# 80 is even
# ...
